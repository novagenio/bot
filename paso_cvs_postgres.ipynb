# %%
import pandas as pd
from sqlalchemy import create_engine
engine = create_engine('postgresql://tradedetail:tradedetail@bvmnglapsboxp01.nngg.corp:5432/tradedetail', client_encoding='utf-8', echo=False)

# %%
datos = pd.read_csv("bot.csv",sep = ';')
datos.head(30)
# Out:
#          seccode   securitylabel       label  spot  tom     8M
# 0   BE0000338476     BGB47JUN1.6  BD EUR GVT   415  131  200.0
# 1   BE0000348574       BGBJUN1.7  BD EUR GVT   819  831  300.0
# 2   BE0000349580     BGB30JUN0.1  BD EUR GVT   528  274  400.0
# 3   BE0000350596     BGB40JUN0.4  BD EUR GVT   444  660  500.0
# 4   DE0001102408       DBR26AUG0  BD EUR GVT   352  416  600.0
# 5   DE0001102424     DBR27AUG0.5  BD EUR GVT   583  159  700.0
# 6   DE0001102481       DBR50AUG0  BD EUR GVT   352  528  800.0
# 7   DE0001102499       DBR30FEB0  BD EUR GVT   348  712  900.0
# 8   DE0001102549       DBR36MAY0  BD EUR GVT   501  592    1.0
# 9   DE0001102564       DBR31AUG0  BD EUR GVT   527  226    1.1
# 10  DE0001135366    DBR40JUL4.75  BD EUR GVT   459  902    1.2
# 11  DE000A0PM5F0   KFW23JAN4.625  BD EUR CRP   412  138    1.3
# 12  DE000A11QTD2   KFW25JAN0.625  BD EUR CRP   116  724    1.4
# 13  DE000A11QTF7   KFW30APR0.375  BD EUR CRP   948  749    1.5
# 14  DE000A11QTG5   KFW22JUL0.625  BD EUR CRP   539  776    1.6
# 15  DE000A11QTK7   KFW35JUL1.375  BD EUR CRP   345  443    1.7
# 16  DE000A168Y22   KFW23MAR0.375  BD EUR CRP   738  209    1.8
# 17  DE000A168Y48    KFW36JUL1.25  BD EUR CRP   988  707    1.9
# 18  DE000A168Y55  KFW26MAR0.3750  BD EUR CRP   716  312    2.0
# 19  DE000A1K0UG6     KFW22JAN2.5  BD EUR CRP   139  577    2.1
# 20  DE000A1R0709     KFW24JUN1.5  BD EUR CRP   426  709    2.2
# 21  DE000A1R07S9   KFW23AUG2.125  BD EUR CRP   942  810    2.3
# 22  DE000A254PM6       KFW25FEB0  BD EUR CRP   819  418    2.4
# 23  DE000A254PP9       KFW27MAR0  BD EUR CRP   917  637    2.5
# 24  DE000A254PS3    KFW25MAR0.01  BD EUR CRP   715  761    2.6
# 25  DE000A289F29       KFW27DEC0  BD EUR CRP   597  455    2.7
# 26  DE000A289RC9       KFW23JUN0  BD EUR CRP   969  451    2.8
# 27  DE000A289RK2       KFW30SEP0  BD EUR CRP   843  516    2.9
# 28  DE000A2BPB50    KFW23SEP0.00  BD EUR CRP   334  658    3.0
# 29  DE000A2DAJ57   KFW24OCT0.125  BD EUR CRP   247  324    3.1

# %%
datos.to_sql('bot', engine,  if_exists='append')

# %%
import psycopg2
import pandas as pd
import pandas.io.sql as psql

conn = psycopg2.connect(database="tradedetail", user="tradedetail", password="tradedetail", host="bvmnglapsboxp01.nngg.corp", port="5432",client_encoding='utf-8')
cur = conn.cursor()
df = psql.read_sql("Select tom from bot where SecCode = 'BE0000350596'", conn)
df.head(5)
# Out:
#    tom
# 0  660
# 1  660

# %%
print(df.iloc[0]['tom'])
# Out:
# 660

# %%
import re

string = "Hey! What's up?"
string = re.sub("\[|\'|\?","",string)
print(string)
# Out:
# Hey! Whats up
